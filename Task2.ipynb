# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.27.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.11.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.4.1)

# %%
import csv
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time

def scrape_product_listing_page(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        products = []

        # Find all product listings on the page
        listings = soup.select('.s-result-item')
        if not listings:
            return []

        for listing in listings:
            # Get product URL
            product_link = listing.select_one('h2 a')
            if not product_link:
                continue  # Skip this product if URL is not found
            product_url = urljoin(url, product_link.get('href'))

            # Get product name
            product_name = listing.select_one('h2 a span').text.strip()

            # Get product price
            product_price = listing.select_one('.a-price .a-offscreen').text.strip()

            # Get product rating and number of reviews
            rating_element = listing.select_one('.a-icon-star span')
            rating = rating_element.text if rating_element else 'Not available'
            num_reviews_element = listing.select_one('.a-size-base')
            num_reviews = num_reviews_element.text.split()[0] if num_reviews_element else '0'

            products.append({
                'URL': product_url,
                'Name': product_name,
                'Price': product_price,
                'Rating': rating,
                'Number of Reviews': num_reviews
            })

        return products
    else:
      return []

def scrape_product_details(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')

        # Get ASIN from the product URL
        asin = url.split('/')[-1].split('?')[0]

        # Get product description
        product_description_element = soup.select_one('#productDescription')
        product_description = product_description_element.text.strip() if product_description_element else 'Not available'

        # Get manufacturer information
        manufacturer_element = soup.select_one('#bylineInfo')
        manufacturer = manufacturer_element.text.strip() if manufacturer_element else 'Not available'

        return {
            'URL': url,
            'ASIN': asin,
            'Product Description': product_description,
            'Manufacturer': manufacturer
        }
    else:
        return None

def main():
    base_url = "https://www.amazon.in/s?k=bags&crid=2M096C61O4MLT&qid=1653308124&sprefix=ba%2Caps%2C283&ref=sr_pg_1"
    num_pages_to_scrape = 50
    product_data = []

    # Scrape product listings from multiple pages
    for page in range(1, num_pages_to_scrape + 1):
        url = base_url + str(page)
        products = scrape_product_listing_page(url)
        product_data.extend(products)

        time.sleep(1)  # Add a small delay to avoid overloading the server

    # Scrape product details for each product URL
    total_products_to_scrape = 200
    product_details_data = []

    for idx, product in enumerate(product_data[:total_products_to_scrape]):
        url = product['URL']
        product_details = scrape_product_details(url)
        if product_details:
            product_details_data.append(product_details)
        print(f"Scraped {idx + 1} out of {total_products_to_scrape} products.")
        time.sleep(1)  # Add a small delay to avoid overloading the server

    # Export the data to a CSV file
    with open('amazon_products_data.csv', 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['URL', 'Name', 'Price', 'Rating', 'Number of Reviews', 'ASIN', 'Product Description', 'Manufacturer']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for product, details in zip(product_data, product_details_data):
            row = {**product, **details}
            writer.writerow(row)

if __name__ == '__main__':
    main()
# Out:
# Scraped 1 out of 200 products.
# Scraped 2 out of 200 products.
# Scraped 3 out of 200 products.
# Scraped 4 out of 200 products.
# Scraped 5 out of 200 products.
# Scraped 6 out of 200 products.
# Scraped 7 out of 200 products.
# Scraped 8 out of 200 products.
# Scraped 9 out of 200 products.
# Scraped 10 out of 200 products.
# Scraped 11 out of 200 products.
# Scraped 12 out of 200 products.
# Scraped 13 out of 200 products.
# Scraped 14 out of 200 products.
# Scraped 15 out of 200 products.
# Scraped 16 out of 200 products.
# Scraped 17 out of 200 products.
# Scraped 18 out of 200 products.
# Scraped 19 out of 200 products.
# Scraped 20 out of 200 products.
# Scraped 21 out of 200 products.
# Scraped 22 out of 200 products.
# Scraped 23 out of 200 products.
# Scraped 24 out of 200 products.
# Scraped 25 out of 200 products.
# Scraped 26 out of 200 products.
# Scraped 27 out of 200 products.
# Scraped 28 out of 200 products.
# Scraped 29 out of 200 products.
# Scraped 30 out of 200 products.
# Scraped 31 out of 200 products.
# Scraped 32 out of 200 products.
# Scraped 33 out of 200 products.
# Scraped 34 out of 200 products.
# Scraped 35 out of 200 products.
# Scraped 36 out of 200 products.
# Scraped 37 out of 200 products.
# Scraped 38 out of 200 products.
# Scraped 39 out of 200 products.
# Scraped 40 out of 200 products.
# Scraped 41 out of 200 products.
# Scraped 42 out of 200 products.
# Scraped 43 out of 200 products.
# Scraped 44 out of 200 products.
# Scraped 45 out of 200 products.
# Scraped 46 out of 200 products.
# Scraped 47 out of 200 products.
# Scraped 48 out of 200 products.
# Scraped 49 out of 200 products.
# Scraped 50 out of 200 products.
# Scraped 51 out of 200 products.
# Scraped 52 out of 200 products.
# Scraped 53 out of 200 products.
# Scraped 54 out of 200 products.
# Scraped 55 out of 200 products.
# Scraped 56 out of 200 products.
# Scraped 57 out of 200 products.
# Scraped 58 out of 200 products.
# Scraped 59 out of 200 products.
# Scraped 60 out of 200 products.
# Scraped 61 out of 200 products.
# Scraped 62 out of 200 products.
# Scraped 63 out of 200 products.
# Scraped 64 out of 200 products.
# Scraped 65 out of 200 products.
# Scraped 66 out of 200 products.
# Scraped 67 out of 200 products.
# Scraped 68 out of 200 products.
# Scraped 69 out of 200 products.
# Scraped 70 out of 200 products.
# Scraped 71 out of 200 products.
# Scraped 72 out of 200 products.
# Scraped 73 out of 200 products.
# Scraped 74 out of 200 products.
# Scraped 75 out of 200 products.
# Scraped 76 out of 200 products.
# Scraped 77 out of 200 products.
# Scraped 78 out of 200 products.
# Scraped 79 out of 200 products.
# Scraped 80 out of 200 products.
# Scraped 81 out of 200 products.
# Scraped 82 out of 200 products.
# Scraped 83 out of 200 products.
# Scraped 84 out of 200 products.
# Scraped 85 out of 200 products.
# Scraped 86 out of 200 products.
# Scraped 87 out of 200 products.
# Scraped 88 out of 200 products.
# Scraped 89 out of 200 products.
# Scraped 90 out of 200 products.
# Scraped 91 out of 200 products.
# Scraped 92 out of 200 products.
# Scraped 93 out of 200 products.
# Scraped 94 out of 200 products.
# Scraped 95 out of 200 products.
# Scraped 96 out of 200 products.
# Scraped 97 out of 200 products.
# Scraped 98 out of 200 products.
# Scraped 99 out of 200 products.
# Scraped 100 out of 200 products.
# Scraped 101 out of 200 products.
# Scraped 102 out of 200 products.
# Scraped 103 out of 200 products.
# Scraped 104 out of 200 products.
# Scraped 105 out of 200 products.
# Scraped 106 out of 200 products.
# Scraped 107 out of 200 products.
# Scraped 108 out of 200 products.
# Scraped 109 out of 200 products.
# Scraped 110 out of 200 products.
# Scraped 111 out of 200 products.
# Scraped 112 out of 200 products.
# Scraped 113 out of 200 products.
# Scraped 114 out of 200 products.
# Scraped 115 out of 200 products.
# Scraped 116 out of 200 products.
# Scraped 117 out of 200 products.
# Scraped 118 out of 200 products.
# Scraped 119 out of 200 products.
# Scraped 120 out of 200 products.
# Scraped 121 out of 200 products.
# Scraped 122 out of 200 products.
# Scraped 123 out of 200 products.
# Scraped 124 out of 200 products.
# Scraped 125 out of 200 products.
# Scraped 126 out of 200 products.
# Scraped 127 out of 200 products.
# Scraped 128 out of 200 products.
# Scraped 129 out of 200 products.
# Scraped 130 out of 200 products.
# Scraped 131 out of 200 products.
# Scraped 132 out of 200 products.
# Scraped 133 out of 200 products.
# Scraped 134 out of 200 products.
# Scraped 135 out of 200 products.
# Scraped 136 out of 200 products.
# Scraped 137 out of 200 products.
# Scraped 138 out of 200 products.
# Scraped 139 out of 200 products.
# Scraped 140 out of 200 products.
# Scraped 141 out of 200 products.
# Scraped 142 out of 200 products.
# Scraped 143 out of 200 products.
# Scraped 144 out of 200 products.
# Scraped 145 out of 200 products.
# Scraped 146 out of 200 products.
# Scraped 147 out of 200 products.
# Scraped 148 out of 200 products.
# Scraped 149 out of 200 products.
# Scraped 150 out of 200 products.
# Scraped 151 out of 200 products.
# Scraped 152 out of 200 products.
# Scraped 153 out of 200 products.
# Scraped 154 out of 200 products.
# Scraped 155 out of 200 products.
# Scraped 156 out of 200 products.
# Scraped 157 out of 200 products.
# Scraped 158 out of 200 products.
# Scraped 159 out of 200 products.
# Scraped 160 out of 200 products.
# Scraped 161 out of 200 products.
# Scraped 162 out of 200 products.
# Scraped 163 out of 200 products.
# Scraped 164 out of 200 products.
# Scraped 165 out of 200 products.
# Scraped 166 out of 200 products.
# Scraped 167 out of 200 products.
# Scraped 168 out of 200 products.
# Scraped 169 out of 200 products.
# Scraped 170 out of 200 products.
# Scraped 171 out of 200 products.
# Scraped 172 out of 200 products.
# Scraped 173 out of 200 products.
# Scraped 174 out of 200 products.
# Scraped 175 out of 200 products.
# Scraped 176 out of 200 products.
# Scraped 177 out of 200 products.
# Scraped 178 out of 200 products.
# Scraped 179 out of 200 products.
# Scraped 180 out of 200 products.
# Scraped 181 out of 200 products.
# Scraped 182 out of 200 products.
# Scraped 183 out of 200 products.
# Scraped 184 out of 200 products.
# Scraped 185 out of 200 products.
# Scraped 186 out of 200 products.
# Scraped 187 out of 200 products.
# Scraped 188 out of 200 products.
# Scraped 189 out of 200 products.
# Scraped 190 out of 200 products.
# Scraped 191 out of 200 products.
# Scraped 192 out of 200 products.
# Scraped 193 out of 200 products.
# Scraped 194 out of 200 products.
# Scraped 195 out of 200 products.
# Scraped 196 out of 200 products.
# Scraped 197 out of 200 products.
# Scraped 198 out of 200 products.
# Scraped 199 out of 200 products.
# Scraped 200 out of 200 products.

# %%
import pandas as pd
df=pd.read_csv('/content/amazon_products_data.csv')
df.shape
# Out:
# (68, 8)

# %%
df.head()
# Out:
#                                                  URL  \
# 0  https://www.amazon.in/Skybags-Brat-Black-Casua...
# 1  https://www.amazon.in/MosQuick%C2%AE-Drawstrin...
# 2  https://www.amazon.in/Backpack-Toddler-Animal-...
# 3  https://www.amazon.in/Blue-Tree-Velvet-Nursery...
# 4  https://www.amazon.in/American-Tourister-BACKP...
#
#                                                 Name   Price         Rating  \
# 0  Wesley Milestone 2.0 Casual Waterproof Laptop ...    ₹598  Not available
# 1  American Tourister Fizz Large Size 32 Ltrs Cas...  ₹1,199  Not available
# 2          Skybags Brat Black 46 Cms Casual Backpack    ₹669  Not available
# 3  MosQuick® Clear large Drawstring Bags Clear Pl...    ₹310  Not available
# 4  MosQuick® Clear large Drawstring Bags Clear Pl...    ₹310  Not available
#
#   Number of Reviews                                 ASIN Product Description  \
# 0            11,801                           ref=sr_1_3       Not available
# 1            54,957  ref=sxin_14_trfobq2av2_0_B09SB5DP5Y       Not available
# 2             5,158  ref=sxin_14_trfobq2av2_4_B08D5RCWV9       Not available
# 3          Amazon’s  ref=sxin_14_trfobq2av2_7_B07QX58HGR       Not available
# 4                69                           ref=sr_1_5       Not available
#
#     Manufacturer
# 0  Not available
# 1  Not available
# 2  Not available
# 3  Not available
# 4  Not available
